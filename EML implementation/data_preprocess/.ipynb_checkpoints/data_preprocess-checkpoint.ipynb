# %%
import pandas as pd

ann = pd.read_csv("scc_ann1.txt", sep=",", header=None)

ann.columns = ["# of inputs", "# of hidden neurons", "# of output neurons",
                          "x1-a1", "x2-a1", "x3-a1", "x4-a1", "bias-a1", 
                          "x1-a2", "x2-a2", "x3-a2", "x4-a2", "bias-a2", 
                          "a1-h", "a2-h", "bias-h"]

ann[:5]
# Out:
#    # of inputs  # of hidden neurons  # of output neurons     x1-a1      x2-a1  \
# 0            4                    2                    1  6.452940   0.017452
# 1            4                    2                    1  3.106838   7.563589
# 2            4                    2                    1  4.883865  44.839871
# 3            4                    2                    1  4.730452  19.398232
# 4            4                    2                    1 -7.168491 -10.095656
#
#       x3-a1     x4-a1    bias-a1      x1-a2      x2-a2      x3-a2      x4-a2  \
# 0  1.582344  2.293046   2.120570   3.951125  12.720648 -19.327801   5.587888
# 1  0.502116  0.637049  12.035630  -2.901302  -3.222112  -0.368567  -0.562298
# 2  1.273451  1.244961  49.177519  -8.832765  -3.129830  -1.009460  11.699963
# 3  0.449241  0.753865  25.709176  17.360476   0.055809  -8.915162   0.499930
# 4 -0.518885 -0.003595   5.933514   5.626838  52.051620   1.486028   1.302745
#
#      bias-a2      a1-h      a2-h    bias-h
# 0   9.382982  0.003064  0.003539  0.795949
# 1  -7.378310  2.385952  1.222035 -0.360292
# 2  -3.010024  0.132635  0.003723  0.673996
# 3  10.339627  4.063120 -0.013630 -3.245987
# 4  57.231061  0.250578  0.137157  0.417379

# %%
ann = pd.read_csv("wld_warm_div20.txt", sep=",", header=None)
