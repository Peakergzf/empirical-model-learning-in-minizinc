lst = sol.split(", ")

assert len(lst) == n

sol_lst = list(map(lambda x : int(x.split("->")[1]) , lst))

print(sol_lst)
# Out:
# [40, 23, 6, 38, 24, 41, 35, 1, 41, 46, 46, 30, 25, 15, 18, 11, 0, 37, 11, 25, 23, 14, 24, 43, 10, 45, 35, 27, 2, 14, 20, 34, 17, 15, 17, 39, 13, 39, 24, 1, 40, 34, 43, 11, 46, 41, 19, 13, 19, 30, 20, 18, 0, 18, 17, 42, 8, 17, 28, 11, 34, 32, 30, 12, 5, 10, 42, 32, 12, 17, 37, 5, 25, 8, 2, 27, 30, 31, 27, 9, 41, 24, 34, 33, 13, 3, 6, 12, 42, 26, 32, 47, 44, 36, 36, 18, 8, 14, 38, 39, 35, 7, 23, 26, 29, 44, 10, 38, 39, 36, 27, 2, 42, 35, 6, 7, 43, 43, 30, 22, 13, 25, 44, 18, 23, 23, 46, 30, 5, 5, 7, 33, 17, 21, 12, 8, 28, 40, 47, 4, 20, 21, 5, 19, 39, 9, 39, 26, 28, 19, 31, 45, 8, 20, 21, 34, 35, 11, 40, 9, 40, 23, 43, 15, 1, 25, 12, 29, 20, 24, 26, 21, 2, 10, 1, 44, 40, 47, 5, 24, 32, 26, 46, 33, 44, 34, 21, 20, 14, 15, 33, 28, 11, 47, 44, 31, 45, 28, 41, 1, 16, 33, 12, 37, 3, 13, 19, 9, 3, 15, 2, 0, 27, 32, 7, 3, 18, 0, 14, 3, 27, 32, 13, 2, 22, 28, 9, 25, 41, 4, 7, 16, 6, 36, 37, 14, 31, 15, 4, 10, 29, 45, 7, 9, 3, 22, 47, 45, 37, 6, 46, 29, 1, 0, 43, 16, 22, 21, 42, 16, 31, 22, 22,
# ...

# %%
ans = [[1 if sol_lst[i] == j else 0 for j in range(m)] for i in range(n)]

for i in range(n):
    assert sum(ans[i]) == 1

for j in range(m):
    s = 0
    for i in range(n):
        s += ans[i][j]
    assert s == n / m
    


ans = [["true" if sol_lst[i] == j else "false" for j in range(m)] for i in range(n)]

for i in range(n):
    print(ans[i])
# Out:
# ['false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'true', 'false', 'false', 'false', 'false', 'false', 'false', 'false']
# ['false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'true', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false']
# ...

# %%
res = "sol = [|"

for i in range(n):
    for j in range(m):
        res += ans[i][j].replace("'", '') + ', '
    res += "\n|"
res += "|];"

with open("data.dzn", 'w') as f:
    f.write(res)
